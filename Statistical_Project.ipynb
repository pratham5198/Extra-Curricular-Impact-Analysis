# %% [markdown]
# **Import the required files**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Upload the data set in Google drive and mount the drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Mount the Google Drive: (1) click mount the drive option and (2) allow to connect the drive**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To access the file path from drive:
# (1) Click drive
#
#
# ![image.png](data:image/png;base64,...)
#
# (2) Copy the path as follows:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Read the file**

# %%
#df = pd.read_csv(FILE, SEP)
df = pd.read_csv("/content/drive/MyDrive/statistics project/Do extracurricular activities help transform personality.csv", sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ac3e7c35b032> in <module>
#       1 #df = pd.read_csv(FILE, SEP)
# ----> 2 df = pd.read_csv("/content/drive/MyDrive/statistics project/Do extracurricular activities help transform personality.csv", sep=',')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/statistics project/Do extracurricular activities help transform personality.csv'

# %% [markdown]
# **Hint:**
# df = pd.read_csv('C:/Users/ABC/Downloads/winequality-white.csv', sep=';')
#
# OR
#
# df = pd.read_csv('C:/Users/ABC/Downloads/StudentsPerformance.csv', sep=',')
#
# OR  (**To read the data from the Drive**)
#
# df = pd.read_csv("/content/drive/MyDrive/Data Sets/StudentsPerformance.csv", sep=',')

# %%
#Show first 5 rows
df.head()
# Out:
#             Name  Gender  Age  activities which activities you do?  \
# 0     Prathamesh    Male   19           1                   sports
# 1       Atharva     Male   19           2        sports;technology
# 2   Kajal Tiwari  Female   19           3     Art;music;technology
# 3  Yash Dhawade     Male   20           1                   sports
# 4     Sonu Yadav    Male   18           1                      Art
#
#   Do you think  it help transform personality more_important  \
# 0                                         yes           both
# 1                                         yes     Acadedmics
# 2                                         yes           both
# 3                                         yes           both
# 4                                         yes           both
#
#   should be compulsory   last_exam  \
# 0                   yes         73
# 1                   yes         81
# 2                   yes         88
# 3                   yes         93
# 4                   yes         66
#
#                                             opinion   review
# 0                                  It refreshes mind    Easy
# 1  They are very encouraging but focus should not...    Easy
# 2  It helps to sprout one as an individual in his...  Normal
# 3                                        It's fun!\n  Normal
# 4                                To do what it takes  Normal

# %%
#Dimensions of the data set
row, col = df.shape
print(row, col)
# Out:
# 73 11

# %%
df.loc[13]
# Out:
# Name                                                                              Siddant naik
# Gender                                                                                    Male
# Age                                                                                         19
# activities                                                                                   1
# which activities you do?                                                                 music
# Do you think  it help transform personality                                                yes
# more_important                                                                            both
# should be compulsory                                                                       yes
# last_exam                                                                                   69
# opinion                                        It should be made compulsory in school collages
# review                                                                                    Easy
# Name: 13, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 11 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Name                                         73 non-null     object
#  1   Gender                                       73 non-null     object
#  2   Age                                          73 non-null     int64
#  3   activities                                   73 non-null     int64
#  4   which activities you do?                     46 non-null     object
#  5   Do you think  it help transform personality  73 non-null     object
#  6   more_important                               73 non-null     object
#  7   should be compulsory                         73 non-null     object
#  8   last_exam                                    73 non-null     int64
#  9   opinion                                      46 non-null     object
#  10  review                                       73 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 6.4+ KB

# %%
#remove spaces in columns names

df. columns = df. columns. str. replace(' ','_')

# %% [markdown]
# **Data Visualization**

# %%
plt.figure(figsize=(6,4))

sns.countplot(x='Gender',data=df)

# %%
plt.figure(figsize=(4, 6))
gender_count = df.groupby('Gender')['Gender'].count()

plt.bar(gender_count.index, gender_count.values)

plt.title('Count of Male and Female)')
# Out:
# Text(0.5, 1.0, 'Count of Male and Female)')

# %%
Gender_count = df.groupby('Gender')['Gender'].count()
Gender_count
# Out:
# Gender
# Female    26
# Male      47
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.title('Grouped by Gender')
plt.pie(Gender_count.values, labels = ['Female', 'Male'], autopct = "%2.2f%%", textprops = {'fontsize':15})
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.distplot(df.activities, bins = 10, kde = False, color = 'orange' )

plt.title('activities', fontsize = 20, color = 'maroon')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'activities')

# %%
sns.boxplot(data = df, x = 'Age')

# %%
sns.boxplot(data = df, x = 'Age', y = 'Gender')

# %%
sns.boxplot(data = df, x = 'Age', y = 'activities')

# %% [markdown]
# Write your observations based on the box plots.

# %% [markdown]
# **`Univariate Analysis`**

# %%
df.describe()
# Out:
#              Age  activities   last_exam
# count  73.000000   73.000000   73.000000
# mean   18.657534    1.328767   76.136986
# std     1.455060    0.667807   97.264718
# min    14.000000    1.000000   39.000000
# 25%    18.000000    1.000000   55.000000
# 50%    19.000000    1.000000   65.000000
# 75%    19.000000    1.000000   77.000000
# max    25.000000    4.000000  888.000000

# %% [markdown]
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.
#
#
#
#
#
# **Task:**
#
# 1. Write about this result and interpretation.
# 2. Try the following code and explain the result:
#
# perc =[0.10, .20, 0.30, .40, 0.50, .60, 0.70, .80, 0.90]
#
# df.describe(percentiles=perc)

# %%
df.Age.value_counts()
# Out:
# 19    35
# 18    17
# 20     9
# 17     4
# 21     2
# 16     2
# 15     2
# 25     1
# 14     1
# Name: Age, dtype: int64

# %% [markdown]
# **Bivariate Analysis**

# %%
plt.figure(figsize=(6,4))

sns.lineplot(data = df, x = 'Age', y='activities')

# %%
plt.figure(figsize=(6,4))

sns.scatterplot(data=df, x='activities',y='last_exam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-08d2b930c1d7> in <module>
# ----> 1 plt.figure(figsize=(6,4))
#       2
#       3 sns.scatterplot(data=df, x='activities',y='last_exam')
#       4
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(), cmap='viridis', annot=False,linewidths=1, linecolor = 'cyan', cbar = True)

# %% [markdown]
# **Description**
#
#
#
#
# A heat map is used to visualize the strength of correlation among variables. It helps find features that are best for Machine Learning model building. The heat map transforms the correlation matrix into color coding.
#
# **Try with various parameters (optional):**
#
# vmin, vmax: Values to anchor the colormap, otherwise they are inferred from the data and other keyword arguments.
#
# cmap: The mapping from data values to color space.
#
# center: The value at which to center the colormap when plotting divergent data.
#
# annot: If True, write the data value in each cell.
#
# fmt: String formatting code to use when adding annotations.
#
# linewidths: Width of the lines that will divide each cell.
#
# linecolor: Color of the lines that will divide each cell.
#
# cbar: Whether to draw a colorbar. (Default is True)

# %% [markdown]
# **Description:**
#
# Correlation between the reading score and writing score is higher. Here, as the reading score increases, the writing score also increases.
#
# (Note: Write the desciption according to your data set)

# %%
np.cov(df.Age, df.last_exam)
# Out:
# array([[ 2.11719939e+00, -7.24410198e+00],
#        [-7.24410198e+00,  9.46042542e+03]])

# %% [markdown]
# **Explanation:**
#
# Variance of math_score = 229.689079
#
# Covariance of math_score, reading_score = 180.817959
#
# Covariance of reading_score, math_score  = 180.817959
#
# Variance of reading_score = 212.952439
#
# cov(a, b) returns [[cov(a,a)  cov(a,b)], [cov(a,b)  cov(b,b)]
#
#
#
# You may compare with the standard deviation given by df.describe()
